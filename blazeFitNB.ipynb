# %% [markdown]
# # Echelle Grating Blaze Function Fitting in Python

# %% [markdown]
# This notebook describes and shows an example of fitting the echelle grating blaze function of the CHIRON Spectrometer in Python.

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
myfigsize = (12.0, 8.0)
myfontsize = 14.
plt.rcParams['figure.figsize'] = myfigsize

# %%
hdulist = fits.open('/tous/mir7/fitspec/141029/achi141029.1143.fits')

# %%
scidata = hdulist[0].data

# %%
scidata.shape
# Out:
# (62, 3200, 2)

# %%
ord = 39
wav = scidata[ord,:,0]
spec = scidata[ord,:,1]
plt.plot(wav, spec)

# %%
from pyutil.blazeFit import blazeFit

# %%
maxrms = 0.005
z = blazeFit(wav, spec, maxrms, numcalls=50)

# %%
#get wavelength range:
wavspread = max(wav) - min(wav)

#center wavelength range about zero:
wavcent = wav - min(wav) - wavspread/2.

#normalize the spectrum:
normspec = spec/max(spec)

#make a function based on those 
#polynomial coefficients:
cfit = np.poly1d(z)

#plot the original spectrum:
plt.plot(wavcent, normspec, color='#1DAB6D')

#overplot the continuum fit
plt.plot(wavcent, cfit(wavcent))

# %%
plt.plot(wav, normspec/cfit(wavcent), color='#1DAB6D')
plt.xlabel('Wavelength [A]')
plt.ylabel('Normalized Flux')
plt.ylim([0,1.1])
plt.xlim([min(wav), max(wav)])
# Out:
# (6547.1362, 6622.519)

# %%
print(z)
# Out:
# [  3.04013031e-12  -5.53105111e-11  -7.96952275e-09   2.30547404e-07
#    7.33804398e-06  -6.07804153e-04  -4.87157730e-03   9.79861969e-01]

# %% [markdown]
# ## Debugging Code

# %% [markdown]
# The code and comments in the section below were used in the debugging process and are most likely not useful.

# %%
from astropy.io import fits

hdulist = fits.open('/tous/mir7/fitspec/141029/achi141029.1143.fits')

# %%
hdulist[0].header
# Out:
# WARNING: VerifyWarning: Verification reported errors: [astropy.io.fits.verify]
# WARNING:astropy:VerifyWarning: Verification reported errors:
# WARNING: VerifyWarning: Card 'GAINS' is not FITS standard (invalid value string: "'5.00000, 5.17000, 4.73000, 5.40000, 1.30900, 1.28300, 1.26600, 1.25").  Fixed 'GAINS' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING:astropy:VerifyWarning: Card 'GAINS' is not FITS standard (invalid value string: "'5.00000, 5.17000, 4.73000, 5.40000, 1.30900, 1.28300, 1.26600, 1.25").  Fixed 'GAINS' card to meet the FITS standard.
# WARNING: VerifyWarning: Note: PyFITS uses zero-based indexing.
#  [astropy.io.fits.verify]
# WARNING:astropy:VerifyWarning: Note: PyFITS uses zero-based indexing.
# SIMPLE  =                    T / Written by IDL:  Fri Oct 31 15:28:19 2014
# BITPIX  =                  -32 / IEEE single precision floating point
# NAXIS   =                    3 /Number of data axes
# NAXIS1  =                    2 /Axis 1 length: 0=wavelength, 1=spectrum
# NAXIS2  =                 3200 /Axis 2 length: extracted pixels along each echel
# NAXIS3  =                   62 /Axis 3 length: number of echelle orders extracte
# EXTEND  =                    T / FITS dataset may contain extensions
# RESOLUTN=        96791.6344732 /Resolution determined from the ThAr.
# THIDNLIN=                 1453 /Number of ThAr lines used for wav soln.
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# BZERO   =                    0 / offset data range to that of unsigned short
# BSCALE  =                    1 / default scaling factor
# OBJECT  = '10700   '           / Name of object observed
# OBSERVER= 'Alberto Miranda'    / observer
# PROPID  = '247     '           / Proposal ID
# OBSID   = 'ct15m.chiron.20141030.071909' / exposure ID
# IMAGETYP= 'object  '           / Type of picture (object, dark, comp, etc)
# CCDSUM  = '3 1     '           / On chip summation (X, Y)
# ROIREQ  = '1 1 4096 4112 (FULL)' / Requested ROI (xstart ystart xlen ylen)
# UTSHUT  = '2014-10-30T07:19:09.345' / UT of shutter open
# DATE    = '2014-10-30T07:25:25' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# NAMPSYX = '2 2     '           / Num amps in y and x (eg. '2 2=quad')
# AMPLIST = '11 12 21 22'        / Readout order in y,x
# TSEC22  = '[734:1416,2057:4112]' / Good section from det 1  amp 22
# ASEC22  = '[4096:2049,4112:2057]' / CCD  section in read order
# CSEC22  = '[734:1416,2057:4112]' / copy from DSEC from det 1  amp 22
# BSEC22  = '[717:733,2057:4112]' / Overscan section from det 1  amp 22
# DSEC22  = '[734:1416,2057:4112]' / Data section from det 1  amp 22
# SCSEC22 = '[2049:4096,2057:4112]' / CCD section from det 1  amp 22
# TSEC12  = '[734:1416,1:2056]'  / Good section from det 1  amp 12
# ASEC12  = '[4096:2049,1:2056]' / CCD  section in read order
# CSEC12  = '[734:1416,1:2056]'  / copy from DSEC from det 1  amp 12
# BSEC12  = '[717:733,1:2056]'   / Overscan section from det 1  amp 12
# DSEC12  = '[734:1416,1:2056]'  / Data section from det 1  amp 12
# SCSEC12 = '[2049:4096,1:2056]' / CCD section from det 1  amp 12
# TSEC11  = '[17:699,1:2056]'    / Good section from det 1  amp 11
# ASEC11  = '[1:2048,1:2056]'    / CCD  section in read order
# CSEC11  = '[17:699,1:2056]'    / copy from DSEC from det 1  amp 11
# BSEC11  = '[700:716,1:2056]'   / Overscan section from det 1  amp 11
# DSEC11  = '[17:699,1:2056]'    / Data section from det 1  amp 11
# SCSEC11 = '[1:2048,1:2056]'    / CCD section from det 1  amp 11
# TSEC21  = '[17:699,2057:4112]' / Good section from det 1  amp 21
# ASEC21  = '[1:2048,4112:2057]' / CCD  section in read order
# CSEC21  = '[17:699,2057:4112]' / copy from DSEC from det 1  amp 21
# BSEC21  = '[700:716,2057:4112]' / Overscan section from det 1  amp 21
# DSEC21  = '[17:699,2057:4112]' / Data section from det 1  amp 21
# SCSEC21 = '[1:2048,2057:4112]' / CCD section from det 1  amp 21
# DETECTOR= 'E2V-4K  '           / Detector Identifier
# FPA     = 'CHIRON  '           / focal plan array
# REXPTIME=                957.5 / requested exposure time
# EXPTIME =              375.107 / Exposure time in secs
# TEXPTIME=              375.107 / requested EXPM exptime
# DARKTIME=              375.107 / dark current time  in secs
# NIMAGES =                    4 / number of images requested in sequence
# DHEINF  = 'MNSN torrent hardware' / controller info
# DHEFIRM = '/home/observer/panview/fpas/_chiron/config/DETECTOR/chiron_sequencer'
# SPEEDMOD= 'normal  '           / speed mode
# GEOMMOD = 'Slit_i2 '           / geometry mode
# PIXTIME =                  8.3 / pixel time (usecs)
# GAIN11  =                  1.3 / Gain for Amp A
# RON11   =                  4.5 / Read Noise for Amp A
# GAIN12  =                  1.3 / Gain for Amp B
# RON12   =                  4.5 / Read Noise for Amp B
# GAIN21  =                  1.3 / Gain for Amp C
# RON21   =                  4.5 / Read Noise for Amp C
# GAIN22  =                  1.3 / Gain for Amp D
# RON22   =                  4.5 / Read Noise for Amp D
# POWSTAT = '3.000   '           / power supplies status (3=OK)
# FPGAFIRM= '211.000 '           / fpga firmware version
# SLOT00  = 'LCB 0x1885A0 2.040000' / dhe board: <type> <serial> <firmware>
# SLOT01  = 'PSM 0x1886C5 2.110000' / dhe board: <type> <serial> <firmware>
# SLOT02  = 'CFG 0xNONE 2.110000' / dhe board: <type> <serial> <firmware>
# SLOT03  = 'PIX 0xNONE 2.070000' / dhe board: <type> <serial> <firmware>
# SLOT04  = 'CCDAFE 0x188400 186D2B 2.060000' / dhe board: <type> <serial> <firmwa
# SLOT07  = 'CB 0xNONE 2.020000' / dhe board: <type> <serial> <firmware>
# SLOT02  = 'TSM 0x3C81D6 NONE'  / dhe board: <type> <serial> <firmware>
# PANID   = '_chiron '           / PAN identification
# COMMENT none
# DHSID   = 'PAN_GFITS'          / dhs identification
# DECKPOS =               3.9095 / decker position (mm)
# DECKER  = 'slit    '           / decker position name
# FOCUS   =              10.2527 / focus position (mm)
# THRES   =             3880000. / signal threshold (expmeter)
# MAXEXP  =               957500 / maximum exposure time in ms (expmeter)
# PMHV    = 'on      '           / PM high voltage status (expmeter)
# CCDTEMP =              -127.99 / detector temperature (C) (OK)
# NECKTEMP=              -152.29 / dewar neck temperature (C) (OK)
# TEMPGRAT=                23.42 / temperature in grating (c) (OK)
# TEMPTLOW=               23.336 / temperature in low table (c) (OK)
# TEMPTCEN=               23.317 / temperature in center table (c) (OK)
# TEMPSTRU=               23.107 / temperature in structure (c) (OK)
# TEMPENCL=                 22.5 / temperature in inst. enclosure (c) (OK)
# TEMPCOUD=               17.473 / temperature in coude room (c) (OK)
# TEMPINST=               22.994 / temperature in instrument body (C) (OK)
# TEMIODIN=                 40.1 / temperature in iodine cell (C) (OK)
# DEWPRESS=                   0. / pressure in dewar (Torr)
# ECHPRESS=                 11.3 / pressure in echelle (mBar) (OK)
# BAROMETE=               779.38 / pressure in instrument (mBar) (OK)
# COMPLAMP= 'none    '           /  comparisson lamp
# IODCELL = 'IN      '           /  iodine cell position
# ID      = '[ct15m.chiron.20141030.071909]' / ID
# OBSERVAT= 'CTIO    '           / Origin of data
# TELESCOP= 'CTIO 1.5 meter telescope' / Specific system
# DATE-OBS= '2014-10-30T07:19:09.4' / date of observation start
# UT      = '07:19:09.4'         / UT of TCS coords
# RA      = '01:44:04.05'        / ra
# DEC     = '-15:56:14.9'        / dec
# EPOCH   =                2000. / epoch
# ALT     = '72.0    '           / altitud
# HA      = '03:25:16.0'         / ha
# ST      = '05:10:04.5'         / sidereal time
# ZD      = '48.9    '           / zenith distance
# AIRMASS = '1.520   '           / airmass
# WEATIME = '2014-10-30 07:24:01' / weather timestamp
# OUTTEMP =                  8.9 / outside temp (C)
# OUTHUM  =                   42 / outside humidity (%)
# OUTPRESS=                 776. / outside pressure (hPa)
# WNDSPEED=                 16.1 / wind speed (mph)
# WNDDIR  =                   31 / wind dir (degrees)
# SEETIME = '2014-10-30 06:09:40' / seeing timestamp
# SEEING  =                2.119 / seeing
# SAIRMASS=                1.388 / seeing airmass
# EMTIMOPN= '2014-10-30T07:19:09.349' / shutter open time from exposure meter
# EMTIMCLS= '2014-10-30T07:25:24.457' / shutter close time from exposure meter
# EMNUMSMP=                 3751 / number of samples
# EMAVG   =              1034.21 / average intensity
# EMAVGSQ =             1100540. / sum of squared intens
# EMPRDSUM=         7.169736E+09 / sum of products of intens and bin number
# EMNETINT=               976.01 / net intensity after bckgrd subtraction
# EMMNWOB = '2014-10-30T07:22:14.167' / mean time without bckgrd subtraction
# EMMNWB  = '2014-10-30T07:22:14.555' / mean time with bckgrd subtraction
# O_BZERO =              32768.0 /Original Data is unsigned Integer
# ROOTDIR = '/'
# LOGDIR  = 'tous/mir7/logsheets/2014/'
# LOGSTDIR= 'tous/mir7/logstructs/'
# IODSPECD= 'tous/mir7/iodspec/'
# PLOTSDIR= '/home/matt/Sites/chi/red/plots/'
# FITSDIR = 'tous/mir7/fitspec/'
# THIDDIR = 'tous/mir7/thid/wavfile/'
# THIDFILE= 'tous/mir7/thid/thidfile/'
# RAWDIR  = 'raw/mir7/'
# IMDIR   = '141029/'
# DATE    = '141029'
# SEQNUM  = '1179'
# VERSIOND= 'Fri Oct 31 15:18:55 2014'
# VERSIONN= '3.0'
# PREFIX_T= 'a'
# PREFIX  = 'chi141029.'
# FLATDIR = 'tous/mir7/flats/'
# BIASDIR = 'tous/mir7/medbias/'
# BIASMODE= '0'
# ORDERDIR= 'tous/mir7/orders/'
# BARYDIR = 'tous/CHIRON/bary/'
# XTRIM   = '0, 3150'
# YTRIM   = '601, 3800'
# READMODE= 'fast, normal'
# NLC     = '0, 0, 0, 0'
# GAINS   = '''5.00000, 5.17000, 4.73000, 5.40000, 1.30900, 1.28300, 1.26600, &'
# CONTINUE  '1.25&'
# RON     = '4.34487'
# GAIN    = '1.30900'
# BINNING = '3, 1'
# MODE    = '2'
# FLATNORM= '1'
# MINFLATV= '10000.000'
# SLICERFL= '1'
# PKCOEFS = '26.4117, 34.9785, 0.114412, 0.00182212'
# PKCOEFS1= '26.451700, 35.045100, 0.11202900, 0.0018838400'
# NORDS   = '62'
# MODES   = 'narrow, slicer, slit, fiber, narrow'
# XWIDS   = '8, 12, 8, 5, 18'
# SLCRXTRA= '2, 26'
# DPKS    = '0, -5, 0, 0, 0'
# BINNINGS= '3x1, 3x1, 3x1, 4x4, 1x1'
# DEBUG   = '0'
# THARFNAM= '/tous/mir7/thid/thidfile/achi141029.1153.thid'

# %%
scidata.shape
# Out:
# (62, 3200, 2)

# %%
#get the full wavelength range to center about zero:
wavspread = max(wav) - min(wav)

#now change the wavelength range:
wavcent0 = wav - min(wav) - wavspread/2.

#normalize the spectrum:
normspec0 = spec/max(spec)

#fit a polynomial to the data:
z0 = np.polyfit(wavcent0, normspec0, 6)
print(z0)
#now make a function based on those 
#polynomial coefficients:
cfit0 = np.poly1d(z0)

#plot the original spectrum:
plt.plot(wavcent0, normspec0)
#and overplot the fit
plt.plot(wavcent0, cfit0(wavcent0))
thresh0 = cfit0(wavcent0)-0.05
plt.plot(wavcent0, thresh0)
# Out:
# [ -2.39859311e-10  -3.33437309e-09   6.96914115e-07   4.83818269e-06
#   -9.00314538e-04  -3.09177122e-03   9.81219635e-01]

# %%
mask1 = np.where(normspec0 > thresh0)[0]

#normalize the spectrum:
newspec1 = normspec0[mask1]

normspec1 = newspec1/max(newspec1)

wavcent1 = wavcent0[mask1]

#fit a polynomial to the data:
z1 = np.polyfit(wavcent1, normspec1, 7)
print(z1)
#now make a function based on those 
#polynomial coefficients:
cfit1 = np.poly1d(z1)

#plot the original spectrum:
plt.plot(wavcent1, normspec1, '.')
#and overplot the fit
plt.plot(wavcent1, cfit1(wavcent1))
thresh1 = cfit1(wavcent1)-0.025
plt.plot(wavcent1, thresh1)
mask2 = np.where(normspec1 > thresh1)[0]
# Out:
# [  8.06949803e-12  -1.10398875e-10  -2.04345309e-08   3.80834951e-07
#    1.56214986e-05  -7.10324351e-04  -5.65864546e-03   9.81527762e-01]

# %%
print(len(normspec1))
print(len(mask2))
# Out:
# 2998
# 2807

# %%
normspec2 = normspec1[mask2]
wavcent2 = wavcent1[mask2]

#fit a polynomial to the data:
z2 = np.polyfit(wavcent2, normspec2, 7)
print(z2)
#now make a function based on those 
#polynomial coefficients:
cfit2 = np.poly1d(z2)

#plot the original spectrum:
plt.plot(wavcent2, normspec2, '.')
#and overplot the fit
plt.plot(wavcent2, cfit2(wavcent2))
thresh2 = cfit2(wavcent2)-0.01
plt.plot(wavcent2, thresh2)
mask3 = np.where(normspec2 > thresh2)[0]
# Out:
# [  5.60728842e-12  -8.47855142e-11  -1.42862635e-08   3.08468128e-07
#    1.15033974e-05  -6.59401696e-04  -5.26300034e-03   9.80416274e-01]

# %%
normspec3 = normspec2[mask3]
wavcent3 = wavcent2[mask3]

#fit a polynomial to the data:
z3 = np.polyfit(wavcent3, normspec3, 7)
print(z3)
#now make a function based on those 
#polynomial coefficients:
cfit3 = np.poly1d(z3)

#plot the original spectrum:
plt.plot(wavcent3, normspec3, '.')
#and overplot the fit
plt.plot(wavcent3, cfit3(wavcent3))
thresh3 = cfit3(wavcent3)-0.01
plt.plot(wavcent3, thresh3)
mask4 = np.where(normspec3 > thresh3)[0]
# Out:
# [  4.29578389e-12  -6.93738074e-11  -1.10776383e-08   2.67811688e-07
#    9.41254387e-06  -6.33011588e-04  -5.08330095e-03   9.80981656e-01]

# %% [markdown]
# #### Now to divide by the blaze fit and calculate the rms

# %% [markdown]
# To determine how good our fit is, we can divide by out continuum fit and check our rms.

# %%
#Here's what the full spectrum looks like:
plt.plot(wavcent0, normspec0/cfit3(wavcent0), '.')

# %%
#And here's our continuum:
plt.plot(wavcent3, normspec3/cfit3(wavcent3), '.')
print('The rms is: {0:.3f})'.format(np.std(normspec3/cfit3(wavcent3))))
# Out:
# The rms is: 0.008)

# %% [markdown]
# ### Making a Recursive Continuum-Fitting Function

# %% [markdown]
# So the fit here is good to 0.8%. Now we'll make the fit good to some user-specified level by creating a recursive function. The recursive function will fit for the continuum, discard points below some threshold, refit the continuum, discard more points, and so on until we hit that user-specified level for the rms of the residuals.

# %%
def blazeFit(wav, spec, maxrms, numcalls=10, curcall=0, verbose=False, showplot=False):
    """PURPOSE: To fit the continuum of an order of an 
    echelle spectrum to model the Blaze Function.
    INPUTS:
    WAV: The wavelength 
    SPEC: The spectrum. This should be the same number of elements 
    (and corrsepond to) the input wavelength array (wav).
    MAXRMS: The threshold criteria for the fit in normalized rms. 
    For example, a threshold of 0.01 will keep iterating until 
    the rms of the residuals of dividing the continuum pixels
    by the Blaze Function comes out to 1%.
    NUMCALLS: The maximum number of recursive iterations to execute.
    CURCALL: Store the current iteration for recursive purposes.
    VERBOSE: Set this to True to print out the iteration, residual
    rms and the threshold value.
    SHOWPLOT: Set this to True to produce a plot of the spectrum, 
    threshold and continuum at every iteration.
    """
    #get wavelength range:
    wavspread = max(wav) - min(wav)

    #center wavelength range about zero:
    wavcent = wav - min(wav) - wavspread/2.

    #normalize the spectrum:
    normspec = spec/max(spec)

    #fit a polynomial to the data:
    z = np.polyfit(wavcent, normspec, 7)
    #print(z)
    
    #make a function based on those 
    #polynomial coefficients:
    cfit = np.poly1d(z)

    #make a lower threshold that is offset
    #below the continuum fit. All points
    #below this fit (i.e. spectral lines) 
    #will be excluded from the fit in the 
    #next iteration.
    thresh = cfit(wavcent) - (0.5 * (1. / (curcall + 1)))

    if (showplot == True):
        #plot the original spectrum:
        plt.plot(wavcent, normspec)
        #overplot the continuum fit
        plt.plot(wavcent, cfit(wavcent))
        plt.plot(wavcent, thresh)

    mask = np.where(normspec > thresh)[0]
    
    residrms = np.std(normspec/cfit(wavcent))
    if (verbose == True):
        print('now in iteration {0}'.format(curcall))
        print('residrms is now {0:.5f}'.format(residrms))
        print('maxrms is {0})'.format(maxrms))
        #print('z is: {}'.format(z))
    
    if ((curcall < numcalls) and (residrms > maxrms)):
        z = blazeFit(wavcent[mask], normspec[mask], maxrms, numcalls=numcalls, curcall=curcall+1)
        
    return z

# %%
maxrms = 0.005
z = blazeFit(wav, spec, maxrms, numcalls=50)

# %%
#get wavelength range:
wavspread = max(wav) - min(wav)

#center wavelength range about zero:
wavcent = wav - min(wav) - wavspread/2.

#normalize the spectrum:
normspec = spec/max(spec)

#make a function based on those 
#polynomial coefficients:
cfit = np.poly1d(z)

#plot the original spectrum:
plt.plot(wavcent, normspec)

#overplot the continuum fit
plt.plot(wavcent, cfit(wavcent))

# %%
plt.plot(wavcent, normspec/cfit(wavcent))

# %% [markdown]
# ### Fitting the Flats

# %% [markdown]
# Another option is to fit the blaze function using the master flat from that night. Aside of pixel-to-pixel variations, this should provide the best solution to what the blaze function looks like on an order by order basis.
